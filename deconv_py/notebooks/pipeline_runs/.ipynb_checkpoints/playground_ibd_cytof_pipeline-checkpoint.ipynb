# %% [markdown]
# #  INIT

# %%
import sys
sys.path.append('../../../')
sys.path.append('../../infras/cellMix/')
sys.path.append('../../infras/cytof_data/')
sys.path.append('../../infras/')
sys.path.append('../../infras/dashboards/')
sys.path.append('../../experiments/')
sys.path.append('../../experiments/pipeline/')
sys.path.append('../../preprocess/intra_variance/')
sys.path.append('../../models/cell_proportions/')
sys.path.append('../../measures/cell_proportions_measures/')
sys.path.append('../../preprocess/cell_specifics/')

# %%
from data_factory import DataFactory
from global_utils import GlobalUtils
from cytof_cell_count_infra import CytofCellCountInfra
from cell_proportions_experiments import  CellProportionsExperiments
import exploration_cytof_plots as cytof_plots
from basic import BasicDeconv
from pp_entropy_based import PpEntropyBased
from pp_dep_de_based import  PpDepDeBased
from cell_proportions_measure import CellProportionsMeasure
from pp_clean_high_intra_var import PpCleanHighIntraVar
from pp_clean_irrelevant_proteins import PpCleanIrrelevantProteins
from pp_empty import PpEmpty
from pp_entropy_based_only_largest import PpEntropyBasedOnlyLargest
from aggregate_intra_variance import AggregateIntraVariance
from pipeline_deconv import PipelineDeconv
from deconv_py.preprocess.base import BasePreprocess as PP_base
from deconv_py.preprocess.cell_specific import CellSpecific as PP_proteins
from deconv_py.preprocess.cell_specifics.pp_svm_signature import PpSvmSignature
from deconv_py.preprocess.cell_specifics.pp_entropy_based_totel_sum import PpEntropyBasedTotelSum
from deconv_py.preprocess.cell_specifics.pp_floor_under_quantile import PpFloorUnderQuantile



from pp_keep_specific_cells  import  PpKeepSpecificCells
from pp_agg_to_specific_cells import PpAggToSpecificCells

# from deconv_py.infras.data_factory import DataFactory
from deconv_py.infras.data_loader import DataLoader
from deconv_py.models.base import Base as Models_base
from deconv_py.models.cell_proportions_models import CellProportions
from deconv_py.models.cell_specific_models import CellSpecificPerPermutation
from deconv_py.experiments.cell_specific import CellSpecificMetricsPlot
from cellMix_coordinator import CellMixCoordinator

import pandas as pd
import numpy as np
from functools import partial
import multiprocessing
from sklearn import pipeline
import itertools
from scipy.optimize import least_squares
from sklearn.metrics import mean_squared_error
from functools import partial
from scipy.optimize import minimize
import scipy.optimize
from itertools import combinations
import matplotlib.pyplot as plt
import seaborn as sns
import pprint
import os
import pickle as pkl 
from sklearn.decomposition import PCA
from IPython.display import display, HTML


# %connect_info
# Out:
# {
#   "shell_port": 61054,
#   "iopub_port": 61055,
#   "stdin_port": 61056,
#   "control_port": 61057,
#   "hb_port": 61058,
#   "ip": "127.0.0.1",
#   "key": "f059b29e-efafe2388d3e4aa05f0c5c43",
#   "transport": "tcp",
#   "signature_scheme": "hmac-sha256",
#   "kernel_name": ""
# }
#
# Paste the above JSON into a file, and connect with:
#     $> jupyter <app> --existing <file>
# or, if you are local, you can connect with just:
#     $> jupyter <app> --existing kernel-36cdd975-7bbb-494b-8dde-0e81a7fb2dcd.json
# or even just:
#     $> jupyter <app> --existing
# if this is the most recent Jupyter kernel you have started.

# %% [markdown]
# # read and build any data

# %%
data_factory = DataFactory()
A_all_vs,B_all_vs = data_factory.load_IBD_all_vs("Intensity",index_func=lambda x:x.split(";")[0],log2_transformation=True)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\kernel\__main__.py:2: DtypeWarning: Columns (5,6,2764,2765,2773,2774,2775,2776) have mixed types. Specify dtype option on import or set low_memory=False.
#   from ipykernel import kernelapp as app

# %% [markdown]
# # run meta analysis

# %% [markdown]
# ## configuration

# %%
spec_cells,agg_spec_cells = PpKeepSpecificCells(),PpAggToSpecificCells()
agg_iv,pp_irl_prot  = AggregateIntraVariance(),PpCleanIrrelevantProteins()
pp_chiv = PpCleanHighIntraVar()
pp_entropy_only_largest, pp_entropy, pp_empty,pp_dep = PpEntropyBasedOnlyLargest(), PpEntropyBased(), PpEmpty(),PpDepDeBased()
pp_svm_signature,pp_totel_sum = PpSvmSignature(),PpEntropyBasedTotelSum()
pp_floor_quantile = PpFloorUnderQuantile()

bd = BasicDeconv()
cpm = CellProportionsMeasure(how="groups")

hyper_configuration = [{"step_name": "floor",
                         "steps": [
                             {"function_name": "floor_quantile", "function": pp_floor_quantile,
                              "params": {}},
                             {"function_name": "PpEmpty_floor", "function": pp_empty,
                              "params": {}}
                         ]},
#                        -----------------------------------
                        {"step_name": "per_cells_filter",
                         "steps": [
                            {"function_name": "kepp_specific_cells", "function": spec_cells,
                                  "params": {}},
                            {"function_name": "agg_to_specific_cells", "function": agg_spec_cells,
                                  "params": {}},
                         {"function_name": "PpEmpty_cells_filt", "function": pp_empty,
                             "params": {}}
                         ]},
                        # -------------------------------
                        {"step_name": "cleanHighIntraVariance",
                        "steps": [
                            {"function_name": "PpCleanHighIntraVar", "function": pp_chiv,
                             "params": {"how": ["std"],"std_trh":[1,4]}},
                        {"function_name": "PpEmpty_clean_iv", "function": pp_empty,
                             "params": {}}]},
                        # -------------------------------
                        {"step_name": "AggregateIntraVariance",
                        "steps": [
                            {"function_name": "AggregateIntraVariance", "function": agg_iv,
                             "params": {"how": ["mean", "median","max"]}}]},
#                                 "params": {"how": ["mean"]}}]},
                       # --------------------------------
                       {"step_name": "cleen_irrelevant_proteins",
                        "steps": [
                            {"function_name": "CleanIrrelevantProteins", "function": pp_irl_prot,
                             "params": {}}]},
                       # --------------------------------
                       {"step_name": "Cytof_X_Building",
                        "steps": [
                            {"function_name": "Cytof_X_Building", "function": pp_empty,
                             "params": {"keep_labels":[True],"with_label_prop":[False]}}]},
                       # --------------------------------
                       {"step_name": "preprocess",
                        "steps": [
                            {"function_name": "pp_totel_sum", "function": pp_totel_sum,
                    "params": {"totel_sum_percentage": [0.001, 0.0001],"with_norm": [False],"number_of_bins" :[0,10,20] ,
                               "only_largest":[True,False]}},
#                             {"function_name": "PpEntropyBased", "function": pp_entropy,
#                              "params": {"n_genes_per_cell": [20,100], "gene_entropy_trh": [1,3],"number_of_bins" :[0,10,20] ,
#                                         "with_norm": [False]}},
                            {"function_name": "PpEntropyBasedOnlyLargest", "function": pp_entropy_only_largest,
                             "params": {"n_genes_per_cell": [80],"number_of_bins" :[0,10,20] ,"with_norm": [ False]}},
                            {"function_name": "PpDepDeBased", "function": pp_dep,
                              "params": {"n_of_genes": [20] ,"is_agg_cells":[True,False]}},
                            {"function_name": "PpSvm", "function": pp_svm_signature,
                  "params": {"n_features": [80], "with_norm": [ False]}},
                            {"function_name": "PpEmpty_prepro", "function": pp_empty,
                             "params": {}}
                        ]},
                       # --------------------------------
                       {"step_name": "deconv",
                        "steps": [
                            {"function_name": "BasicDeconv", "function": bd,
                             "params": {"normalize": [True], "cellMix": [ False]}}]}]

hyper_measure_configuration = [
    {"step_name": "measure",
     "steps": [
         {"function_name": "CellProportionsMeasure", "function": cpm,
#           "params": {"how": ["correlation","RMSE","MI"],"with_pvalue":[True],"with_iso_test":[False]}}]}]
          "params": {"how": ["correlation","entropy"],"with_pvalue":[True],"with_iso_test":[False]}}]}]

_pipe = PipelineDeconv(hyper_configuration=hyper_configuration,
                                 hyper_measure_configuration=hyper_measure_configuration)

# %% [markdown]
# ## run

# %%
meta_results = _pipe.run_cytof_pipeline(A_all_vs, B_all_vs)
# Out:
#   0%|                                                                                         | 0/1026 [00:00<?, ?it/s]C:\Users\Shenorr\AppData\Roaming\Python\Python36\site-packages\sklearn\base.py:197: FutureWarning: From version 0.24, get_params will raise an AttributeError if a parameter cannot be retrieved as an instance attribute. Previously it would return None.
#   FutureWarning)
#   3%|██▎                                                                           | 31/1026 [12:37<6:28:04, 23.40s/it]C:\Users\Shenorr\AppData\Roaming\Python\Python36\site-packages\sklearn\base.py:197: FutureWarning: From version 0.24, get_params will raise an AttributeError if a parameter cannot be retrieved as an instance attribute. Previously it would return None.
#   FutureWarning)
#   5%|███▊                                                                          | 50/1026 [20:20<6:10:39, 22.79s/it]C:\Users\Shenorr\AppData\Roaming\Python\Python36\site-packages\sklearn\base.py:197: FutureWarning: From version 0.24, get_params will raise an AttributeError if a parameter cannot be retrieved as an instance attribute. Previously it would return None.
#   FutureWarning)
#   7%|█████▏                                                                        | 69/1026 [28:04<6:02:32, 22.73s/it]C:\Users\Shenorr\AppData\Roaming\Python\Python36\site-packages\sklearn\base.py:197: FutureWarning: From version 0.24, get_params will raise an AttributeError if a parameter cannot be retrieved as an instance attribute. Previously it would return None.
#   FutureWarning)
#   9%|██████▋                                                                       | 88/1026 [38:42<3:46:07, 14.46s/it]C:\Users\Shenorr\AppData\Roaming\Python\Python36\site-packages\sklearn\base.py:197: FutureWarning: From version 0.24, get_params will raise an AttributeError if a parameter cannot be retrieved as an instance attribute. Previously it would return None.
#   FutureWarning)
#  10%|████████                                                                     | 107/1026 [42:23<2:43:06, 10.65s/it]C:\Users\Shenorr\AppData\Roaming\Python\Python36\site-packages\sklearn\base.py:197: FutureWarning: From version 0.24, get_params will raise an AttributeError if a parameter cannot be retrieved as an instance attribute. Previously it would return None.
#   FutureWarning)
#  12%|█████████▍                                                                   | 126/1026 [45:34<1:49:29,  7.30s/it]C:\Users\Shenorr\AppData\Roaming\Python\Python36\site-packages\sklearn\base.py:197: FutureWarning: From version 0.24, get_params will raise an AttributeError if a parameter cannot be retrieved as an instance attribute. Previously it would return None.
#   FutureWarning)
#  14%|██████████▉                                                                  | 145/1026 [48:14<1:49:50,  7.48s/it]C:\Users\Shenorr\AppData\Roaming\Python\Python36\site-packages\sklearn\base.py:197: FutureWarning: From version 0.24, get_params will raise an AttributeError if a parameter cannot be retrieved as an instance attribute. Previously it would return None.
#   FutureWarning)
#  16%|████████████▎                                                                | 164/1026 [50:52<1:42:37,  7.14s/it]C:\Users\Shenorr\AppData\Roaming\Python\Python36\site-packages\sklearn\base.py:197: FutureWarning: From version 0.24, get_params will raise an AttributeError if a parameter cannot be retrieved as an instance attribute. Previously it would return None.
#   FutureWarning)
#  18%|█████████████▋                                                               | 183/1026 [54:04<2:17:57,  9.82s/it]C:\Users\Shenorr\AppData\Roaming\Python\Python36\site-packages\sklearn\base.py:197: FutureWarning: From version 0.24, get_params will raise an AttributeError if a parameter cannot be retrieved as an instance attribute. Previously it would return None.
#   FutureWarning)
#  20%|███████████████▏                                                             | 202/1026 [57:04<2:15:57,  9.90s/it]C:\Users\Shenorr\AppData\Roaming\Python\Python36\site-packages\sklearn\base.py:197: FutureWarning: From version 0.24, get_params will raise an AttributeError if a parameter cannot be retrieved as an instance attribute. Previously it would return None.
#   FutureWarning)
#  22%|████████████████▏                                                          | 221/1026 [1:00:02<2:12:09,  9.85s/it]C:\Users\Shenorr\AppData\Roaming\Python\Python36\site-packages\sklearn\base.py:197: FutureWarning: From version 0.24, get_params will raise an AttributeError if a parameter cannot be retrieved as an instance attribute. Previously it would return None.
#   FutureWarning)
#  23%|█████████████████▌                                                         | 240/1026 [1:03:02<2:09:04,  9.85s/it]C:\Users\Shenorr\AppData\Roaming\Python\Python36\site-packages\sklearn\base.py:197: FutureWarning: From version 0.24, get_params will raise an AttributeError if a parameter cannot be retrieved as an instance attribute. Previously it would return None.
#   FutureWarning)
#  25%|██████████████████▉                                                        | 259/1026 [1:06:03<2:06:29,  9.90s/it]C:\Users\Shenorr\AppData\Roaming\Python\Python36\site-packages\sklearn\base.py:197: FutureWarning: From version 0.24, get_params will raise an AttributeError if a parameter cannot be retrieved as an instance attribute. Previously it would return None.
#   FutureWarning)
#  27%|████████████████████▎                                                      | 278/1026 [1:09:03<2:03:49,  9.93s/it]C:\Users\Shenorr\AppData\Roaming\Python\Python36\site-packages\sklearn\base.py:197: FutureWarning: From version 0.24, get_params will raise an AttributeError if a parameter cannot be retrieved as an instance attribute. Previously it would return None.
#   FutureWarning)
#  29%|█████████████████████▋                                                     | 297/1026 [1:11:29<1:23:55,  6.91s/it]C:\Users\Shenorr\AppData\Roaming\Python\Python36\site-packages\sklearn\base.py:197: FutureWarning: From version 0.24, get_params will raise an AttributeError if a parameter cannot be retrieved as an instance attribute. Previously it would return None.
#   FutureWarning)
#  31%|███████████████████████                                                    | 316/1026 [1:13:37<1:22:14,  6.95s/it]C:\Users\Shenorr\AppData\Roaming\Python\Python36\site-packages\sklearn\base.py:197: FutureWarning: From version 0.24, get_params will raise an AttributeError if a parameter cannot be retrieved as an instance attribute. Previously it would return None.
#   FutureWarning)
#  33%|████████████████████████▍                                                  | 335/1026 [1:15:51<1:26:25,  7.50s/it]C:\Users\Shenorr\AppData\Roaming\Python\Python36\site-packages\sklearn\base.py:197: FutureWarning: From version 0.24, get_params will raise an AttributeError if a parameter cannot be retrieved as an instance attribute. Previously it would return None.
#   FutureWarning)
#  35%|█████████████████████████▉                                                 | 354/1026 [1:18:48<1:59:31, 10.67s/it]C:\Users\Shenorr\AppData\Roaming\Python\Python36\site-packages\sklearn\base.py:197: FutureWarning: From version 0.24, get_params will raise an AttributeError if a parameter cannot be retrieved as an instance attribute. Previously it would return None.
#   FutureWarning)
#  35%|██████████████████████████▎                                                | 360/1026 [1:20:11<2:55:58, 15.85s/it]C:\Users\Shenorr\AppData\Roaming\Python\Python36\site-packages\scipy\stats\_distn_infrastructure.py:2664: RuntimeWarning: invalid value encountered in true_divide
#   pk = 1.0*pk / np.sum(pk, axis=axis, keepdims=True)
#  36%|███████████████████████████▎                                               | 373/1026 [1:22:23<1:55:33, 10.62s/it]C:\Users\Shenorr\AppData\Roaming\Python\Python36\site-packages\sklearn\base.py:197: FutureWarning: From version 0.24, get_params will raise an AttributeError if a parameter cannot be retrieved as an instance attribute. Previously it would return None.
#   FutureWarning)
#  37%|███████████████████████████▋                                               | 379/1026 [1:23:46<2:50:53, 15.85s/it]C:\Users\Shenorr\AppData\Roaming\Python\Python36\site-packages\scipy\stats\_distn_infrastructure.py:2664: RuntimeWarning: invalid value encountered in true_divide
#   pk = 1.0*pk / np.sum(pk, axis=axis, keepdims=True)
#  38%|████████████████████████████▋                                              | 392/1026 [1:25:59<1:51:58, 10.60s/it]C:\Users\Shenorr\AppData\Roaming\Python\Python36\site-packages\sklearn\base.py:197: FutureWarning: From version 0.24, get_params will raise an AttributeError if a parameter cannot be retrieved as an instance attribute. Previously it would return None.
#   FutureWarning)
#  39%|█████████████████████████████                                              | 398/1026 [1:27:25<2:52:02, 16.44s/it]C:\Users\Shenorr\AppData\Roaming\Python\Python36\site-packages\scipy\stats\_distn_infrastructure.py:2664: RuntimeWarning: invalid value encountered in true_divide
#   pk = 1.0*pk / np.sum(pk, axis=axis, keepdims=True)
#  40%|██████████████████████████████                                             | 411/1026 [1:29:40<1:52:29, 10.98s/it]C:\Users\Shenorr\AppData\Roaming\Python\Python36\site-packages\sklearn\base.py:197: FutureWarning: From version 0.24, get_params will raise an AttributeError if a parameter cannot be retrieved as an instance attribute. Previously it would return None.
#   FutureWarning)
#
/it]C:\Users\Shenorr\AppData\Roaming\Python\Python36\site-packages\scipy\stats\_distn_infrastructure.py:2664: RuntimeWarning: invalid value encountered in true_divide
#   pk = 1.0*pk / np.sum(pk, axis=axis, keepdims=True)
#  88%|███████████████████████████████████████████████████████████████████▉         | 905/1026 [2:53:22<26:03, 12.92s/it]C:\Users\Shenorr\AppData\Roaming\Python\Python36\site-packages\sklearn\base.py:197: FutureWarning: From version 0.24, get_params will raise an AttributeError if a parameter cannot be retrieved as an instance attribute. Previously it would return None.
#   FutureWarning)
#  89%|████████████████████████████████████████████████████████████████████▎        | 911/1026 [2:55:00<35:57, 18.76s/it]C:\Users\Shenorr\AppData\Roaming\Python\Python36\site-packages\scipy\stats\_distn_infrastructure.py:2664: RuntimeWarning: invalid value encountered in true_divide
#   pk = 1.0*pk / np.sum(pk, axis=axis, keepdims=True)
#  90%|█████████████████████████████████████████████████████████████████████▎       | 924/1026 [2:57:39<21:33, 12.68s/it]C:\Users\Shenorr\AppData\Roaming\Python\Python36\site-packages\sklearn\base.py:197: FutureWarning: From version 0.24, get_params will raise an AttributeError if a parameter cannot be retrieved as an instance attribute. Previously it would return None.
#   FutureWarning)
#  91%|█████████████████████████████████████████████████████████████████████▊       | 930/1026 [2:59:20<30:50, 19.28s/it]C:\Users\Shenorr\AppData\Roaming\Python\Python36\site-packages\scipy\stats\_distn_infrastructure.py:2664: RuntimeWarning: invalid value encountered in true_divide
#   pk = 1.0*pk / np.sum(pk, axis=axis, keepdims=True)
#  92%|██████████████████████████████████████████████████████████████████████▊      | 943/1026 [3:01:52<17:00, 12.30s/it]C:\Users\Shenorr\AppData\Roaming\Python\Python36\site-packages\sklearn\base.py:197: FutureWarning: From version 0.24, get_params will raise an AttributeError if a parameter cannot be retrieved as an instance attribute. Previously it would return None.
#   FutureWarning)
#  92%|███████████████████████████████████████████████████████████████████████▏     | 949/1026 [3:03:32<24:19, 18.95s/it]C:\Users\Shenorr\AppData\Roaming\Python\Python36\site-packages\scipy\stats\_distn_infrastructure.py:2664: RuntimeWarning: invalid value encountered in true_divide
#   pk = 1.0*pk / np.sum(pk, axis=axis, keepdims=True)
#  94%|████████████████████████████████████████████████████████████████████████▏    | 962/1026 [3:06:10<13:40, 12.82s/it]C:\Users\Shenorr\AppData\Roaming\Python\Python36\site-packages\sklearn\base.py:197: FutureWarning: From version 0.24, get_params will raise an AttributeError if a parameter cannot be retrieved as an instance attribute. Previously it would return None.
#   FutureWarning)
#  94%|████████████████████████████████████████████████████████████████████████▋    | 968/1026 [3:07:51<18:37, 19.27s/it]C:\Users\Shenorr\AppData\Roaming\Python\Python36\site-packages\scipy\stats\_distn_infrastructure.py:2664: RuntimeWarning: invalid value encountered in true_divide
#   pk = 1.0*pk / np.sum(pk, axis=axis, keepdims=True)
#  96%|█████████████████████████████████████████████████████████████████████████▌   | 981/1026 [3:09:42<06:35,  8.78s/it]C:\Users\Shenorr\AppData\Roaming\Python\Python36\site-packages\sklearn\base.py:197: FutureWarning: From version 0.24, get_params will raise an AttributeError if a parameter cannot be retrieved as an instance attribute. Previously it would return None.
#   FutureWarning)
#  96%|██████████████████████████████████████████████████████████████████████████   | 987/1026 [3:11:07<10:59, 16.91s/it]C:\Users\Shenorr\AppData\Roaming\Python\Python36\site-packages\scipy\stats\_distn_infrastructure.py:2664: RuntimeWarning: invalid value encountered in true_divide
#   pk = 1.0*pk / np.sum(pk, axis=axis, keepdims=True)
#  97%|██████████████████████████████████████████████████████████████████████████  | 1000/1026 [3:12:59<03:50,  8.85s/it]C:\Users\Shenorr\AppData\Roaming\Python\Python36\site-packages\sklearn\base.py:197: FutureWarning: From version 0.24, get_params will raise an AttributeError if a parameter cannot be retrieved as an instance attribute. Previously it would return None.
#   FutureWarning)
#  98%|██████████████████████████████████████████████████████████████████████████▌ | 1006/1026 [3:14:27<05:49, 17.48s/it]C:\Users\Shenorr\AppData\Roaming\Python\Python36\site-packages\scipy\stats\_distn_infrastructure.py:2664: RuntimeWarning: invalid value encountered in true_divide
#   pk = 1.0*pk / np.sum(pk, axis=axis, keepdims=True)
#  99%|███████████████████████████████████████████████████████████████████████████▍| 1019/1026 [3:16:14<01:00,  8.62s/it]C:\Users\Shenorr\AppData\Roaming\Python\Python36\site-packages\sklearn\base.py:197: FutureWarning: From version 0.24, get_params will raise an AttributeError if a parameter cannot be retrieved as an instance attribute. Previously it would return None.
#   FutureWarning)
# 100%|███████████████████████████████████████████████████████████████████████████▉| 1025/1026 [3:17:38<00:16, 16.69s/it]C:\Users\Shenorr\AppData\Roaming\Python\Python36\site-packages\scipy\stats\_distn_infrastructure.py:2664: RuntimeWarning: invalid value encountered in true_divide
#   pk = 1.0*pk / np.sum(pk, axis=axis, keepdims=True)
# 100%|████████████████████████████████████████████████████████████████████████████| 1026/1026 [3:17:45<00:00, 11.56s/it]

# %%
meta_results.drop_duplicates()
# Out:
#       entropy  corrMean  corrPval PpFloorUnderQuantile_quantile  \
# 0    0.728307     0.348     0.121                           0.1
# 1    0.728307     0.348     0.141                           0.1
# 2    0.422460     0.342     0.066                           0.1
# 3    0.422460     0.342     0.061                           0.1
# 4    0.682184     0.353     0.389                           0.1
# ..        ...       ...       ...                           ...
# 967  0.189408     0.347     0.697                           NaN
# 968  0.071387     0.366     0.894                           NaN
# 969  0.564237     0.566     0.030                           NaN
# 970  0.174076     0.323     0.172                           NaN
# 971  0.372796     0.398     0.015                           NaN
#
#     PpKeepSpecificCells_cells_list PpCleanHighIntraVar_how  \
# 0                          ['NOT_B                     std
# 1                          ['NOT_B                     std
# 2                          ['NOT_B                     std
# 3                          ['NOT_B                     std
# 4                          ['NOT_B                     std
# ..                             ...                     ...
# 967                            NaN                     NaN
# 968                            NaN                     NaN
# 969                            NaN                     NaN
# 970                            NaN                     NaN
# 971                            NaN                     NaN
#
#     PpCleanHighIntraVar_std_trh PpCleanHighIntraVar_range_trh  \
# 0                             1                             2
# 1                             1                             2
# 2                             1                             2
# 3                             1                             2
# 4                             1                             2
# ..                          ...                           ...
# 967                         NaN                           NaN
# 968                         NaN                           NaN
# 969                         NaN                           NaN
# 970                         NaN                           NaN
# 971                         NaN                           NaN
#
#     PpCleanHighIntraVar_number_of_zeros AggregateIntraVariance_how  ...  \
# 0                                     2                       mean  ...
# 1                                     2                       mean  ...
# 2                                     2                       mean  ...
# 3                                     2                       mean  ...
# 4                                     2                       mean  ...
# ..                                  ...                        ...  ...
# 967                                 NaN                        max  ...
# 968                                 NaN                        max  ...
# 969                                 NaN                        max  ...
# 970                                 NaN                        max  ...
# 971                                 NaN                        max  ...
#
#     PpEntropyBasedOnlyLargest_with_norm  \
# 0                                   NaN
# 1                                   NaN
# 2                                   NaN
# 3                                   NaN
# 4                                   NaN
# ..                                  ...
# 967                               False
# 968                               False
# 969                                 NaN
# 970                                 NaN
# 971                                 NaN
#
#     PpEntropyBasedOnlyLargest_low_intra_var_trh  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
# ..                                          ...
# 967                                        None
# 968                                        None
# 969                                         NaN
# 970                                         NaN
# 971                                         NaN
#
#     PpEntropyBasedOnlyLargest_number_of_bins PpDepDeBased_n_genes_per_cell  \
# 0                                        NaN                           NaN
# 1                                        NaN                           NaN
# 2                                        NaN                           NaN
# 3                                        NaN                           NaN
# 4                                        NaN                           NaN
# ..                                       ...                           ...
# 967                                       10                           NaN
# 968                                       20                           NaN
# 969                                      NaN                            20
# 970                                      NaN                           NaN
# 971                                      NaN                           NaN
#
#     PpDepDeBased_intansity_type PpDepDeBased_is_agg_cells  \
# 0                           NaN                       NaN
# 1                           NaN                       NaN
# 2                           NaN                       NaN
# 3                           NaN                       NaN
# 4                           NaN                       NaN
# ..                          ...                       ...
# 967                         NaN                       NaN
# 968                         NaN                       NaN
# 969                     Intensi                     False
# 970                         NaN                       NaN
# 971                         NaN                       NaN
#
#     PpDepDeBased_n_of_genes PpSvmSignature_n_features  \
# 0                       NaN                       NaN
# 1                       NaN                       NaN
# 2                       NaN                       NaN
# 3                       NaN                       NaN
# 4                       NaN                       NaN
# ..                      ...                       ...
# 967                     NaN                       NaN
# 968                     NaN                       NaN
# 969                      20                       NaN
# 970                     NaN                        80
# 971                     NaN                       NaN
#
#      PpSvmSignature_with_norm PpAggToSpecificCells_cells_mapping
# 0                         NaN                                NaN
# 1                         NaN                                NaN
# 2                         NaN                                NaN
# 3                         NaN                                NaN
# 4                         NaN                                NaN
# ..                        ...                                ...
# 967                       NaN                                NaN
# 968                       NaN                                NaN
# 969                       NaN                                NaN
# 970                     False                                NaN
# 971                       NaN                                NaN
#
# [972 rows x 30 columns]

# %%
meta_results.sort_values(by="corrMean",ascending=False)[["entropy","corrMean","corrPval","uuid"]]
# Out:
#       entropy  corrMean  corrPval        uuid
# 465  0.584102     0.670     0.273  2855453888
# 357  0.584102     0.670     0.338  3675605498
# 411  0.584102     0.670     0.308  1616052592
# 779  0.471860     0.610     0.010  1075791390
# 929  0.203691     0.574     0.000  2930761200
# ..        ...       ...       ...         ...
# 674  0.567715    -0.200     0.000  3345995966
# 796  0.392989    -0.201     0.152  2519979048
# 908  0.346188    -0.204     0.535   420985626
# 909  0.346188    -0.204     0.404   553890944
# 962  0.367011    -0.206     0.571  2312618514
#
# [972 rows x 4 columns]

# %%
# meta_results[~meta_results["PpEntropyBasedTotelSum_with_norm"].isna()][["corrMean","corrPval","entropy","uuid"]]

# %% [markdown]
# ## result

# %%
_res = meta_results[(meta_results["corrPval"] < 0.15)].sort_values(by="corrMean",ascending=False)
_res = _res.drop_duplicates(subset=["corrMean","entropy"])
_res[_res["entropy"]>1].head(10).iloc[3]
# Out:
# entropy                                           1.00952
# corrMean                                             0.39
# corrPval                                            0.071
# PpFloorUnderQuantile_quantile                         NaN
# PpKeepSpecificCells_cells_list                        NaN
# PpCleanHighIntraVar_how                               NaN
# PpCleanHighIntraVar_std_trh                           NaN
# PpCleanHighIntraVar_range_trh                         NaN
# PpCleanHighIntraVar_number_of_zeros                   NaN
# AggregateIntraVariance_how                           mean
# PpEmpty_with_label_prop                             False
# PpEntropyBasedTotelSum_totel_sum_percentage        0.0001
# PpEntropyBasedTotelSum_with_norm                    False
# PpEntropyBasedTotelSum_low_intra_var_trh             None
# PpEntropyBasedTotelSum_only_largest                  True
# PpEntropyBasedTotelSum_number_of_bins                   0
# BasicDeconv_normalize                                True
# BasicDeconv_cellMix                                 False
# uuid                                           2498654492
# PpEntropyBasedOnlyLargest_n_genes_per_cell            NaN
# PpEntropyBasedOnlyLargest_with_norm                   NaN
# PpEntropyBasedOnlyLargest_low_intra_var_trh           NaN
# PpEntropyBasedOnlyLargest_number_of_bins              NaN
# PpDepDeBased_n_genes_per_cell                         NaN
# PpDepDeBased_intansity_type                           NaN
# PpDepDeBased_is_agg_cells                             NaN
# PpDepDeBased_n_of_genes                               NaN
# PpSvmSignature_n_features                             NaN
# PpSvmSignature_with_norm                              NaN
# PpAggToSpecificCells_cells_mapping                    NaN
# Name: 924, dtype: object

# %%
_res = meta_results.sort_values(by="corrMean",ascending=False)[["corrMean","corrPval","entropy","uuid"]]
_res[(_res["corrMean"] > 0.35)&(_res["entropy"] > 1)&(_res["corrPval"] < 0.05)].sort_values(by="entropy")
# Out:
#      corrMean  corrPval   entropy        uuid
# 531     0.433       0.0  1.050325  1246567846
# 530     0.433       0.0  1.050325  1140098712
# 348     0.428       0.0  1.119007  2446133214
# 349     0.428       0.0  1.119007  2545843436
# 671     0.523       0.0  1.281708  3052684496
# 670     0.523       0.0  1.281708  2926166942

# %%
# meta_results[(meta_results["rmsePval"] < 0.15)&(meta_results["corrPval"] < 0.15)].sort_values(by="corrMean",ascending=False).head(10)

# %% [markdown]
# # best results

# %% [markdown]
# ## get best results

# %%
def build_distance_matrix() :
    uuid_to_results = {}
    for uuid in meta_results["uuid"] : 
        params = meta_results[meta_results["uuid"] == int(uuid)].T.copy(deep=True).dropna()
        
        best_results_and_known = _pipe.load_results_from_archive(uuid)
        best_results=best_results_and_known["result"]
        res_values = best_results.sort_index(axis=0).sort_index(axis=1).values
        
        uuid_to_results[uuid] = res_values
    
    results = {}
    looked_uuids = {}
    for uuid,res in uuid_to_results.items():
        if uuid in looked_uuids.keys():
            continue
            
        neighbors = [] 
        for sec_uuid,sec_res in uuid_to_results.items():
            if (res == sec_res).all() :
                neighbors.append(sec_uuid)
                looked_uuids[sec_uuid] = sec_uuid
        if len(neighbors) > 1 :
            results[uuid] = neighbors
    
    clusters = [] 
    for _,cluster in  results.items():
        uuids = [] 
        for uuid in cluster : 
            params = meta_results[meta_results["uuid"] == int(uuid)].T.copy(deep=True).dropna()
            uuids.append(params)
        clusters.append(pd.concat(uuids,axis=1))
        
    
    return clusters
    
    
def plot_correlation_per_cell(uuids) : 
    if type(uuids) is str : 
        uuids = [uuids]
    
    max_corr_per_cell = {}
    best_param_per_cell = {}
    
    for uuid in meta_results["uuid"] : 
        params = meta_results[meta_results["uuid"] == int(uuid)].T.copy(deep=True).dropna()
        
        best_results_and_known = _pipe.load_results_from_archive(uuid)
        best_results=best_results_and_known["result"]
        best_known=best_results_and_known["known"]
        mapping = GlobalUtils.get_corospanding_mixtures_map(best_known,best_results)
        best_known = best_known.rename(columns=mapping)
        best_known = best_known[[col for col in mapping.values()]]

        mutual_col = best_known.columns.intersection(best_results.columns)
        best_results = best_results[mutual_col]
        best_known = best_known[mutual_col]

        corr_per_cell =  best_results.T.corrwith(best_known.T,method="spearman")
        
        for cell in corr_per_cell.index : 
            if cell in max_corr_per_cell.keys() : 
                if corr_per_cell[cell] > max_corr_per_cell[cell] :
                    max_corr_per_cell[cell] = corr_per_cell[cell]
                    best_param_per_cell[cell] = params
            else : 
                max_corr_per_cell[cell] = corr_per_cell[cell]
                best_param_per_cell[cell] = params
    
    return max_corr_per_cell,best_param_per_cell

def plot_results_vs_known_pca(best_results,best_known):
    pca = PCA(n_components=2)
    pca.fit(pd.concat([best_results,best_known],axis=1).T)

    deconv_principalcomp = pca.transform(best_results.T)
    known_principalcomp = pca.transform(best_known.T)

    deconv_principalDf =pd.DataFrame(data = deconv_principalcomp
                 , columns = ['principal component 1', 'principal component 2'],index = best_results.columns)
    known_principalDf = pd.DataFrame(data = known_principalcomp
                 , columns = ['principal component 1', 'principal component 2'],index = best_known.columns)

    deconv_principalDf["color"] = "b"
    known_principalDf["color"] = "r"

    principalDf = deconv_principalDf.append(known_principalDf)
    fig = plt.figure(figsize = (25,15))
    ax = fig.add_subplot(1,1,1) 
    ax.set_xlabel('Principal Component 1', fontsize = 15)
    ax.set_ylabel('Principal Component 2', fontsize = 15)
    ax.set_title('blue - deconvolution result,red -  known proportions', fontsize = 20)

    ax.scatter(principalDf['principal component 1'], principalDf['principal component 2'],c=principalDf['color'], s = 50)

    for mixture in range(deconv_principalcomp.shape[0]):
        deconv_point = deconv_principalcomp[mixture,:]
        known_point = known_principalcomp[mixture,:]
        plt.plot([deconv_point[0],known_point[0]],[deconv_point[1],known_point[1]], ':')

    for i, txt in enumerate(principalDf.index):
        ax.annotate(txt, (principalDf['principal component 1'].iloc[i], principalDf['principal component 2'].iloc[i]))

def describe_results(uuids,with_per_mixture_plot = False,with_mixtures_pca = False) : 
    if type(uuids) is str : 
        uuids = [uuids]
    
    for uuid in uuids : 
        params = meta_results[meta_results["uuid"] == int(uuid)].T.copy(deep=True).dropna()
        print("params : ")
        display(HTML(params.to_html()))


        best_results_and_known = _pipe.load_results_from_archive(uuid)
        best_results=best_results_and_known["result"]
        best_known=best_results_and_known["known"]
        mapping = GlobalUtils.get_corospanding_mixtures_map(best_known,best_results)
        best_known = best_known.rename(columns=mapping)
        best_known = best_known[[col for col in mapping.values()]]

        mutual_col = best_known.columns.intersection(best_results.columns)
        best_results = best_results[mutual_col]
        best_known = best_known[mutual_col]

        print("mixtures : ")
        display(HTML(best_results.to_html()))

        print("mixtures details :")
        display(HTML(best_results.corrwith(best_known,method="spearman").describe().to_frame().to_html()))

        cytof_plots.plot_mass_to_cytof_scatter_all_on_one(best_results,best_known,best_results)
        if with_per_mixture_plot : 
            cytof_plots.plot_mass_to_cytof_scatter(best_results,best_known,best_results)
        if with_mixtures_pca : 
            plot_results_vs_known_pca(best_results,best_known)

# %%
max_corr_per_cell,best_param_per_cell = plot_correlation_per_cell("2855453888")

# %%
max_corr_per_cell

# %%
for cell,param in best_param_per_cell.items():
    print(cell)
    display(HTML(param.to_html()))

# %%
_meta_results = meta_results.copy(deep=True)
_meta_results = _meta_results.set_index("corrMean").sort_index(ascending = True)
p_value = 0.15
measures_cols = [col.split("Mean")[0] for col in  _meta_results.columns if "Mean" in col]

for measure,style in zip(measures_cols,['-ro','-bo','-go']) : 
    measures_series = _meta_results[[measure+"Mean",measure+"Pval"]]
    measures_series[measures_series[measure+"Pval"]<p_value][measure+"Mean"].plot(style = style,legend =True)

# %%
ts_results=meta_results[~meta_results["PpEntropyBasedTotelSum_with_norm"].isna()][["corrMean","corrStd","corrPval","uuid"]].head(10)["uuid"]
describe_results(ts_results)

# %%
describe_results("1246567846",with_mixtures_pca=True)
# Out:
# params :
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>531</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>entropy</th>
#       <td>1.05033</td>
#     </tr>
#     <tr>
#       <th>corrMean</th>
#       <td>0.433</td>
#     </tr>
#     <tr>
#       <th>corrPval</th>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>PpKeepSpecificCells_cells_list</th>
#       <td>['NOT_B</td>
#     </tr>
#     <tr>
#       <th>PpCleanHighIntraVar_how</th>
#       <td>std</td>
#     </tr>
#     <tr>
#       <th>PpCleanHighIntraVar_std_trh</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>PpCleanHighIntraVar_range_trh</th>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>PpCleanHighIntraVar_number_of_zeros</th>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>AggregateIntraVariance_how</th>
#       <td>max</td>
#     </tr>
#     <tr>
#       <th>PpEmpty_with_label_prop</th>
#       <td>False</td>
#     </tr>
#     <tr>
#       <th>PpEntropyBasedTotelSum_totel_sum_percentage</th>
#       <td>0.0001</td>
#     </tr>
#     <tr>
#       <th>PpEntropyBasedTotelSum_with_norm</th>
#       <td>False</td>
#     </tr>
#     <tr>
#       <th>PpEntropyBasedTotelSum_low_intra_var_trh</th>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>PpEntropyBasedTotelSum_only_largest</th>
#       <td>False</td>
#     </tr>
#     <tr>
#       <th>PpEntropyBasedTotelSum_number_of_bins</th>
#       <td>10</td>
#     </tr>
#     <tr>
#       <th>BasicDeconv_normalize</th>
#       <td>True</td>
#     </tr>
#     <tr>
#       <th>BasicDeconv_cellMix</th>
#       <td>False</td>
#     </tr>
#     <tr>
#       <th>uuid</th>
#       <td>1246567846</td>
#     </tr>
#   </tbody>
# </table>
# mixtures :
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>38_v1</th>
#       <th>42_v1</th>
#       <th>42_v2</th>
#       <th>42_v3</th>
#       <th>44_v1</th>
#       <th>44_v2</th>
#       <th>44_v3</th>
#       <th>46_v1</th>
#       <th>46_v3</th>
#       <th>47_v1</th>
#       <th>38_v2</th>
#       <th>47_v2</th>
#       <th>47_v3</th>
#       <th>48_v1</th>
#       <th>48_v2</th>
#       <th>48_v3</th>
#       <th>29_v1</th>
#       <th>29_v2</th>
#       <th>29_v3</th>
#       <th>30_v1</th>
#       <th>30_v2</th>
#       <th>38_v3</th>
#       <th>30_v3</th>
#       <th>31_v1</th>
#       <th>31_v2</th>
#       <th>31_v3</th>
#       <th>32_v1</th>
#       <th>32_v2</th>
#       <th>32_v3</th>
#       <th>33_v1</th>
#       <th>33_v3</th>
#       <th>39_v1</th>
#       <th>35_v1</th>
#       <th>35_v2</th>
cytof_plots.plot_mass_to_cytof_scatter(best_results,best_known,best_results)

# %%
cytof_plots.plot_mass_to_cytof_scatter_per_cell(best_results,best_known,best_results)

# %% [markdown]
# # test

# %%
best_known

# %%
a = best_known["42_v1"].rename(columns={"42_v1":"mixture"})
b = best_known["42_v2"].rename(columns={"42_v2":"mixture"})
c= best_known["44_v2"].rename(columns={"44_v2":"mixture"})

a_df = best_known["42_v1"].to_frame().rename(columns={"42_v1":"mixture"})
b_df = best_known["42_v2"] .to_frame().rename(columns={"42_v2":"mixture"})
c_df= best_known["44_v2"].to_frame().rename(columns={"44_v2":"mixture"})

# %%
cytof_plots.plot_mass_to_cytof_scatter(a_df,b_df,a_df)

# %%
def concordance_proportions_measure(_x,_y):
#     _x = np.log(x)
#     _y = np.log(y)
    return _x.cov(_y)/(_x.var()+_y.var())

# %%
concordance_proportions_measure(a,b)

# %%
concordance_proportions_measure(a,c)

# %%
concordance_proportions_measure(b,c)

# %%
concordance_proportions_measure(best_known["42_v1"],best_results["42_v1"])

# %%
percentile = 1 - stats.percentileofscore(list(range(300)), 298)/100
percentile

# %%
a = pd.DataFrame(columns=["cell","tissue section","small area"]) 
# b = pd.DataFrame(columns=["value","main_group","sup_group"])

# %%
for i in range(100) : 
    main_group = np.ceil(i/30) 
    sup_group = np.ceil(i/10) 
    value = i
    
    a.loc[i,:] = (value,main_group,sup_group)
a

# %%
a_dfs = {}
for i in range(100) : 
    main_group = np.ceil(i/30) 
    sup_group = np.ceil(i/10) 
    value = i
    
    if main_group in a_dfs.keys():
        if sup_group in a_dfs[main_group].keys() :
            a_dfs[main_group][sup_group].append(value)
        else : 
            a_dfs[main_group][sup_group] = [value]
    else:
        a_dfs[main_group] = {sup_group:[value]}

# %%
import random
res = pd.DataFrame(a_dfs)
corr_res = []
for i in range(100):
    new_list = [] 
    for mg in random.sample(range(5),5):
        for sg in random.sample(range(11),11):
            if type(res.loc[sg,mg]) is not float :
                new_list += random.sample(res.loc[sg,mg],len(res.loc[sg,mg]))
    corr =abs(np.corrcoef(new_list,range(100))[0][1]) 
    corr_res.append(corr)

# %%
res

# %%
plt.hist(corr_res)

# %%
another_corr_res = []
for i in range(100):
    new_list = [] 
    for mg in range(5):
        for sg in random.sample(range(11),11):
            if type(res.loc[sg,mg]) is not float :
                new_list += random.sample(res.loc[sg,mg],len(res.loc[sg,mg]))
    corr =abs(np.corrcoef(new_list,range(100))[0][1]) 
    another_corr_res.append(corr)

# %%
plt.hist(another_corr_res)

# %%
def partial_random():
    t = np.array(range(5))
    r = random.sample(range(5),3)
    t[r]=random.sample(r,3)
    return t

another2_corr_res = []
for i in range(100):
    new_list = [] 
    for mg in partial_random():
        for sg in random.sample(range(11),11):
            if type(res.loc[sg,mg]) is not float :
                new_list += random.sample(res.loc[sg,mg],len(res.loc[sg,mg]))
    corr =abs(np.corrcoef(new_list,range(100))[0][1]) 
    another2_corr_res.append(corr)

# %%
plt.hist(another2_corr_res)

# %%
blob = {"a":"aa"}

# %%
blob.
