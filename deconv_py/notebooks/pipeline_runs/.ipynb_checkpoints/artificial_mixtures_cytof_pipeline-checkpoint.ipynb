# %% [markdown]
# #  INIT

# %%
import sys
sys.path.append('../../../')
sys.path.append('../../infras/cellMix/')
sys.path.append('../../infras/cytof_data/')
sys.path.append('../../infras/')
sys.path.append('../../infras/dashboards/')
sys.path.append('../../experiments/')
sys.path.append('../../experiments/pipeline/')
sys.path.append('../../preprocess/intra_variance/')
sys.path.append('../../models/cell_proportions/')
sys.path.append('../../measures/cell_proportions_measures/')
sys.path.append('../../preprocess/cell_specifics/')

# %%
from data_factory import DataFactory
from global_utils import GlobalUtils
from cytof_cell_count_infra import CytofCellCountInfra
from cell_proportions_experiments import  CellProportionsExperiments
import exploration_cytof_plots as cytof_plots
from basic import BasicDeconv
from pp_entropy_based import PpEntropyBased
from pp_dep_de_based import  PpDepDeBased
from cell_proportions_measure import CellProportionsMeasure
from pp_clean_high_intra_var import PpCleanHighIntraVar
from pp_clean_irrelevant_proteins import PpCleanIrrelevantProteins
from pp_empty import PpEmpty
from pp_entropy_based_only_largest import PpEntropyBasedOnlyLargest
from aggregate_intra_variance import AggregateIntraVariance
from pipeline_deconv import PipelineDeconv
from deconv_py.preprocess.base import BasePreprocess as PP_base
from deconv_py.preprocess.cell_specific import CellSpecific as PP_proteins
from deconv_py.preprocess.cell_specifics.pp_svm_signature import PpSvmSignature
from deconv_py.preprocess.cell_specifics.pp_entropy_based_totel_sum import PpEntropyBasedTotelSum
from deconv_py.preprocess.cell_specifics.pp_floor_under_quantile import PpFloorUnderQuantile



from pp_keep_specific_cells  import  PpKeepSpecificCells
from pp_agg_to_specific_cells import PpAggToSpecificCells

# from deconv_py.infras.data_factory import DataFactory
from deconv_py.infras.data_loader import DataLoader
from deconv_py.models.base import Base as Models_base
from deconv_py.models.cell_proportions_models import CellProportions
from deconv_py.models.cell_specific_models import CellSpecificPerPermutation
from deconv_py.experiments.cell_specific import CellSpecificMetricsPlot
from cellMix_coordinator import CellMixCoordinator

import pandas as pd
import numpy as np
from functools import partial
import multiprocessing
from sklearn import pipeline
import itertools
from scipy.optimize import least_squares
from sklearn.metrics import mean_squared_error
from functools import partial
from scipy.optimize import minimize
import scipy.optimize
from itertools import combinations
import matplotlib.pyplot as plt
import seaborn as sns
import pprint
import os
import pickle as pkl 
from sklearn.decomposition import PCA
from IPython.display import display, HTML


# %connect_info
# Out:
# {
#   "shell_port": 61054,
#   "iopub_port": 61055,
#   "stdin_port": 61056,
#   "control_port": 61057,
#   "hb_port": 61058,
#   "ip": "127.0.0.1",
#   "key": "f059b29e-efafe2388d3e4aa05f0c5c43",
#   "transport": "tcp",
#   "signature_scheme": "hmac-sha256",
#   "kernel_name": ""
# }
#
# Paste the above JSON into a file, and connect with:
#     $> jupyter <app> --existing <file>
# or, if you are local, you can connect with just:
#     $> jupyter <app> --existing kernel-36cdd975-7bbb-494b-8dde-0e81a7fb2dcd.json
# or even just:
#     $> jupyter <app> --existing
# if this is the most recent Jupyter kernel you have started.

# %% [markdown]
# # read and build any data

# %%
data_factory = DataFactory()
A_all_vs,B_all_vs = data_factory.load_IBD_all_vs("Intensity",index_func=lambda x:x.split(";")[0],log2_transformation=True)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\kernel\__main__.py:2: DtypeWarning: Columns (5,6,2764,2765,2773,2774,2775,2776) have mixed types. Specify dtype option on import or set low_memory=False.
#   from ipykernel import kernelapp as app

# %% [markdown]
# # run meta analysis

# %% [markdown]
# ## configuration

# %%
spec_cells,agg_spec_cells = PpKeepSpecificCells(),PpAggToSpecificCells()
agg_iv,pp_irl_prot  = AggregateIntraVariance(),PpCleanIrrelevantProteins()
pp_chiv = PpCleanHighIntraVar()
pp_entropy_only_largest, pp_entropy, pp_empty,pp_dep = PpEntropyBasedOnlyLargest(), PpEntropyBased(), PpEmpty(),PpDepDeBased()
pp_svm_signature,pp_totel_sum = PpSvmSignature(),PpEntropyBasedTotelSum()
pp_floor_quantile = PpFloorUnderQuantile()

bd = BasicDeconv()
cpm = CellProportionsMeasure(how="groups")

hyper_configuration = [{"step_name": "floor",
                         "steps": [
                             {"function_name": "floor_quantile", "function": pp_floor_quantile,
                              "params": {}},
                             {"function_name": "PpEmpty_floor", "function": pp_empty,
                              "params": {}}
                         ]},
#                        -----------------------------------
                        {"step_name": "per_cells_filter",
                         "steps": [
                            {"function_name": "kepp_specific_cells", "function": spec_cells,
                                  "params": {}},
                            {"function_name": "agg_to_specific_cells", "function": agg_spec_cells,
                                  "params": {}},
                         {"function_name": "PpEmpty_cells_filt", "function": pp_empty,
                             "params": {}}
                         ]},
                        # -------------------------------
                        {"step_name": "cleanHighIntraVariance",
                        "steps": [
                            {"function_name": "PpCleanHighIntraVar", "function": pp_chiv,
                             "params": {"how": ["std"],"std_trh":[1,2]}},
                        {"function_name": "PpEmpty_clean_iv", "function": pp_empty,
                             "params": {}}]},
                        # -------------------------------
                        {"step_name": "AggregateIntraVariance",
                        "steps": [
                            {"function_name": "AggregateIntraVariance", "function": agg_iv,
                             "params": {"how": ["mean", "median","max"]}}]},
#                                 "params": {"how": ["mean"]}}]},
                       # --------------------------------
                       {"step_name": "cleen_irrelevant_proteins",
                        "steps": [
                            {"function_name": "CleanIrrelevantProteins", "function": pp_irl_prot,
                             "params": {}}]},
                       # --------------------------------
                       {"step_name": "Cytof_X_Building",
                        "steps": [
                            {"function_name": "Cytof_X_Building", "function": pp_empty,
                             "params": {"keep_labels":[True],"with_label_prop":[False]}}]},
                       # --------------------------------
                       {"step_name": "preprocess",
                        "steps": [
                            {"function_name": "pp_totel_sum", "function": pp_totel_sum,
                    "params": {"totel_sum_percentage": [0.001, 0.0001],"with_norm": [True,False],"number_of_bins" :[0,10,20] ,
#                             "params": {"totel_sum_percentage": [0.001, 0.0001],"with_norm": [False],"number_of_bins" :[0,20] ,
                               "only_largest":[True,False]}},
                            {"function_name": "PpEntropyBased", "function": pp_entropy,
                             "params": {"n_genes_per_cell": [20,100], "gene_entropy_trh": [1,3],"number_of_bins" :[0,10,20] ,
                                        "with_norm": [True,False]}},
                            {"function_name": "PpEntropyBasedOnlyLargest", "function": pp_entropy_only_largest,
                             "params": {"n_genes_per_cell": [20,80],"number_of_bins" :[0,10,20] ,"with_norm": [True, False]}},
                            {"function_name": "PpDepDeBased", "function": pp_dep,
                              "params": {"n_of_genes": [20,80] ,"is_agg_cells":[True,False]}},
                            {"function_name": "PpSvm", "function": pp_svm_signature,
                  "params": {"n_features": [20,80], "with_norm": [ False]}},
                            {"function_name": "PpEmpty_prepro", "function": pp_empty,
                             "params": {}}
                        ]},
                       # --------------------------------
                       {"step_name": "deconv",
                        "steps": [
                            {"function_name": "BasicDeconv", "function": bd,
                             "params": {"normalize": [True], "cellMix": [ False]}}]}]

hyper_measure_configuration = [
    {"step_name": "measure",
     "steps": [
         {"function_name": "CellProportionsMeasure", "function": cpm,
#           "params": {"how": ["correlation","RMSE","MI"],"with_pvalue":[True],"with_iso_test":[False]}}]}]
          "params": {"how": ["correlation","entropy"],"with_pvalue":[True],"with_iso_test":[False]}}]}]

_pipe = PipelineDeconv(hyper_configuration=hyper_configuration,
                                 hyper_measure_configuration=hyper_measure_configuration)

# %% [markdown]
# ## run

# %%
meta_results = _pipe.run_cytof_pipeline(A_all_vs, B_all_vs,per_cell_analysis = True)
# Out:
#   0%|                                                                                         | 0/3618 [00:00<?, ?it/s]C:\Users\Shenorr\AppData\Roaming\Python\Python36\site-packages\sklearn\base.py:197: FutureWarning: From version 0.24, get_params will raise an AttributeError if a parameter cannot be retrieved as an instance attribute. Previously it would return None.
#   FutureWarning)
#   2%|█▎                                                                           | 64/3618 [01:50<15:57:00, 16.16s/it]C:\Users\Shenorr\AppData\Roaming\Python\Python36\site-packages\scipy\stats\_distn_infrastructure.py:2664: RuntimeWarning: invalid value encountered in true_divide
#   pk = 1.0*pk / np.sum(pk, axis=axis, keepdims=True)
#   3%|█▉                                                                           | 91/3618 [08:44<16:17:49, 16.63s/it]C:\Users\Shenorr\AppData\Roaming\Python\Python36\site-packages\sklearn\base.py:197: FutureWarning: From version 0.24, get_params will raise an AttributeError if a parameter cannot be retrieved as an instance attribute. Previously it would return None.
#   FutureWarning)
#   4%|██▊                                                                         | 131/3618 [20:17<26:21:26, 27.21s/it]C:\Users\Shenorr\AppData\Roaming\Python\Python36\site-packages\scipy\stats\_distn_infrastructure.py:2664: RuntimeWarning: invalid value encountered in true_divide
#   pk = 1.0*pk / np.sum(pk, axis=axis, keepdims=True)
#   4%|███▎                                                                        | 158/3618 [27:10<14:51:16, 15.46s/it]C:\Users\Shenorr\AppData\Roaming\Python\Python36\site-packages\sklearn\base.py:197: FutureWarning: From version 0.24, get_params will raise an AttributeError if a parameter cannot be retrieved as an instance attribute. Previously it would return None.
#   FutureWarning)
#   5%|████▏                                                                       | 198/3618 [37:39<24:15:22, 25.53s/it]C:\Users\Shenorr\AppData\Roaming\Python\Python36\site-packages\scipy\stats\_distn_infrastructure.py:2664: RuntimeWarning: invalid value encountered in true_divide
#   pk = 1.0*pk / np.sum(pk, axis=axis, keepdims=True)
#   6%|████▋                                                                       | 225/3618 [44:15<13:48:47, 14.66s/it]C:\Users\Shenorr\AppData\Roaming\Python\Python36\site-packages\sklearn\base.py:197: FutureWarning: From version 0.24, get_params will raise an AttributeError if a parameter cannot be retrieved as an instance attribute. Previously it would return None.
#   FutureWarning)
#   7%|█████▌                                                                      | 265/3618 [54:55<26:24:22, 28.35s/it]C:\Users\Shenorr\AppData\Roaming\Python\Python36\site-packages\scipy\stats\_distn_infrastructure.py:2664: RuntimeWarning: invalid value encountered in true_divide
#   pk = 1.0*pk / np.sum(pk, axis=axis, keepdims=True)
#   8%|█████▉                                                                    | 292/3618 [1:08:30<16:16:23, 17.61s/it]C:\Users\Shenorr\AppData\Roaming\Python\Python36\site-packages\sklearn\base.py:197: FutureWarning: From version 0.24, get_params will raise an AttributeError if a parameter cannot be retrieved as an instance attribute. Previously it would return None.
#   FutureWarning)
#   9%|██████▊                                                                   | 332/3618 [1:19:12<24:25:29, 26.76s/it]C:\Users\Shenorr\AppData\Roaming\Python\Python36\site-packages\scipy\stats\_distn_infrastructure.py:2664: RuntimeWarning: invalid value encountered in true_divide
#   pk = 1.0*pk / np.sum(pk, axis=axis, keepdims=True)
#  10%|███████▎                                                                  | 359/3618 [1:26:08<13:59:31, 15.46s/it]C:\Users\Shenorr\AppData\Roaming\Python\Python36\site-packages\sklearn\base.py:197: FutureWarning: From version 0.24, get_params will raise an AttributeError if a parameter cannot be retrieved as an instance attribute. Previously it would return None.
#   FutureWarning)
#  11%|████████▏                                                                 | 399/3618 [1:36:34<22:45:19, 25.45s/it]C:\Users\Shenorr\AppData\Roaming\Python\Python36\site-packages\scipy\stats\_distn_infrastructure.py:2664: RuntimeWarning: invalid value encountered in true_divide
#   pk = 1.0*pk / np.sum(pk, axis=axis, keepdims=True)
#  12%|████████▋                                                                 | 426/3618 [1:41:59<10:16:11, 11.58s/it]C:\Users\Shenorr\AppData\Roaming\Python\Python36\site-packages\sklearn\base.py:197: FutureWarning: From version 0.24, get_params will raise an AttributeError if a parameter cannot be retrieved as an instance attribute. Previously it would return None.
#   FutureWarning)
#  13%|█████████▌                                                                | 466/3618 [1:50:21<21:23:06, 24.42s/it]C:\Users\Shenorr\AppData\Roaming\Python\Python36\site-packages\scipy\stats\_distn_infrastructure.py:2664: RuntimeWarning: invalid value encountered in true_divide
#   pk = 1.0*pk / np.sum(pk, axis=axis, keepdims=True)
#  14%|██████████                                                                | 493/3618 [1:55:45<10:22:59, 11.96s/it]C:\Users\Shenorr\AppData\Roaming\Python\Python36\site-packages\sklearn\base.py:197: FutureWarning: From version 0.24, get_params will raise an AttributeError if a parameter cannot be retrieved as an instance attribute. Previously it would return None.
#   FutureWarning)
#  15%|██████████▉                                                               | 533/3618 [2:04:07<20:01:46, 23.37s/it]C:\Users\Shenorr\AppData\Roaming\Python\Python36\site-packages\scipy\stats\_distn_infrastructure.py:2664: RuntimeWarning: invalid value encountered in true_divide
#   pk = 1.0*pk / np.sum(pk, axis=axis, keepdims=True)
#  15%|███████████▌                                                               | 560/3618 [2:09:33<9:59:20, 11.76s/it]C:\Users\Shenorr\AppData\Roaming\Python\Python36\site-packages\sklearn\base.py:197: FutureWarning: From version 0.24, get_params will raise an AttributeError if a parameter cannot be retrieved as an instance attribute. Previously it would return None.
#   FutureWarning)
#  17%|████████████▎                                                             | 600/3618 [2:18:19<21:59:17, 26.23s/it]C:\Users\Shenorr\AppData\Roaming\Python\Python36\site-packages\scipy\stats\_distn_infrastructure.py:2664: RuntimeWarning: invalid value encountered in true_divide
#   pk = 1.0*pk / np.sum(pk, axis=axis, keepdims=True)
#  17%|████████████▊                                                             | 627/3618 [2:25:04<13:47:38, 16.60s/it]C:\Users\Shenorr\AppData\Roaming\Python\Python36\site-packages\sklearn\base.py:197: FutureWarning: From version 0.24, get_params will raise an AttributeError if a parameter cannot be retrieved as an instance attribute. Previously it would return None.
#   FutureWarning)
#  18%|█████████████▊                                                             | 667/3618 [2:34:54<8:51:26, 10.81s/it]C:\Users\Shenorr\AppData\Roaming\Python\Python36\site-packages\scipy\stats\_distn_infrastructure.py:2664: RuntimeWarning: invalid value encountered in true_divide
#   pk = 1.0*pk / np.sum(pk, axis=axis, keepdims=True)
#  19%|██████████████▏                                                           | 694/3618 [2:41:38<12:35:13, 15.50s/it]C:\Users\Shenorr\AppData\Roaming\Python\Python36\site-packages\sklearn\base.py:197: FutureWarning: From version 0.24, get_params will raise an AttributeError if a parameter cannot be retrieved as an instance attribute. Previously it would return None.
#   FutureWarning)
#  20%|███████████████▏                                                           | 734/3618 [2:51:29<8:37:58, 10.78s/it]C:\Users\Shenorr\AppData\Roaming\Python\Python36\site-packages\scipy\stats\_distn_infrastructure.py:2664: RuntimeWarning: invalid value encountered in true_divide
#   pk = 1.0*pk / np.sum(pk, axis=axis, keepdims=True)
#  21%|███████████████▌                                                          | 761/3618 [2:57:57<11:58:40, 15.09s/it]C:\Users\Shenorr\AppData\Roaming\Python\Python36\site-packages\sklearn\base.py:197: FutureWarning: From version 0.24, get_params will raise an AttributeError if a parameter cannot be retrieved as an instance attribute. Previously it would return None.
#   FutureWarning)
#  22%|████████████████▌                                                          | 801/3618 [3:08:12<8:54:34, 11.39s/it]C:\Users\Shenorr\AppData\Roaming\Python\Python36\site-packages\scipy\stats\_distn_infrastructure.py:2664: RuntimeWarning: invalid value encountered in true_divide
#   pk = 1.0*pk / np.sum(pk, axis=axis, keepdims=True)
#  23%|████████████████▉                                                         | 828/3618 [3:15:06<12:18:50, 15.89s/it]C:\Users\Shenorr\AppData\Roaming\Python\Python36\site-packages\sklearn\base.py:197: FutureWarning: From version 0.24, get_params will raise an AttributeError if a parameter cannot be retrieved as an instance attribute. Previously it would return None.
#   FutureWarning)
#
/it]C:\Users\Shenorr\AppData\Roaming\Python\Python36\site-packages\sklearn\base.py:197: FutureWarning: From version 0.24, get_params will raise an AttributeError if a parameter cannot be retrieved as an instance attribute. Previously it would return None.
#   FutureWarning)
#  92%|██████████████████████████████████████████████████████████████████▉      | 3315/3618 [23:34:43<1:17:58, 15.44s/it]../../measures/cell_proportions_measures\cell_proportions_measure.py:236: RuntimeWarning: divide by zero encountered in longlong_scalars
#   non = np.round(measure.isna().sum() / measure.count() , 3)
#  93%|███████████████████████████████████████████████████████████████████▌     | 3347/3618 [23:43:55<2:14:46, 29.84s/it]C:\Users\Shenorr\AppData\Roaming\Python\Python36\site-packages\scipy\stats\_distn_infrastructure.py:2664: RuntimeWarning: invalid value encountered in true_divide
#   pk = 1.0*pk / np.sum(pk, axis=axis, keepdims=True)
#  93%|███████████████████████████████████████████████████████████████████▌     | 3349/3618 [23:44:32<1:47:10, 23.90s/it]C:\Users\Shenorr\AppData\Roaming\Python\Python36\site-packages\scipy\stats\_distn_infrastructure.py:2664: RuntimeWarning: invalid value encountered in true_divide
#   pk = 1.0*pk / np.sum(pk, axis=axis, keepdims=True)
#  93%|████████████████████████████████████████████████████████████████████     | 3374/3618 [23:51:18<1:06:10, 16.27s/it]C:\Users\Shenorr\AppData\Roaming\Python\Python36\site-packages\sklearn\base.py:197: FutureWarning: From version 0.24, get_params will raise an AttributeError if a parameter cannot be retrieved as an instance attribute. Previously it would return None.
#   FutureWarning)
#  93%|██████████████████████████████████████████████████████████████████████     | 3382/3618 [23:53:20<58:52, 14.97s/it]../../measures/cell_proportions_measures\cell_proportions_measure.py:236: RuntimeWarning: divide by zero encountered in longlong_scalars
#   non = np.round(measure.isna().sum() / measure.count() , 3)
#  94%|████████████████████████████████████████████████████████████████████▉    | 3414/3618 [24:02:51<1:33:43, 27.57s/it]C:\Users\Shenorr\AppData\Roaming\Python\Python36\site-packages\scipy\stats\_distn_infrastructure.py:2664: RuntimeWarning: invalid value encountered in true_divide
#   pk = 1.0*pk / np.sum(pk, axis=axis, keepdims=True)
#  94%|████████████████████████████████████████████████████████████████████▉    | 3416/3618 [24:03:29<1:18:06, 23.20s/it]C:\Users\Shenorr\AppData\Roaming\Python\Python36\site-packages\scipy\stats\_distn_infrastructure.py:2664: RuntimeWarning: invalid value encountered in true_divide
#   pk = 1.0*pk / np.sum(pk, axis=axis, keepdims=True)
#  95%|███████████████████████████████████████████████████████████████████████▎   | 3441/3618 [24:08:29<34:20, 11.64s/it]C:\Users\Shenorr\AppData\Roaming\Python\Python36\site-packages\sklearn\base.py:197: FutureWarning: From version 0.24, get_params will raise an AttributeError if a parameter cannot be retrieved as an instance attribute. Previously it would return None.
#   FutureWarning)
#  96%|███████████████████████████████████████████████████████████████████████▉   | 3473/3618 [24:14:43<27:14, 11.27s/it]../../measures/cell_proportions_measures\cell_proportions_measure.py:236: RuntimeWarning: divide by zero encountered in longlong_scalars
#   non = np.round(measure.isna().sum() / measure.count() , 3)
#  96%|████████████████████████████████████████████████████████████████████████▏  | 3481/3618 [24:17:11<42:12, 18.49s/it]C:\Users\Shenorr\AppData\Roaming\Python\Python36\site-packages\scipy\stats\_distn_infrastructure.py:2664: RuntimeWarning: invalid value encountered in true_divide
#   pk = 1.0*pk / np.sum(pk, axis=axis, keepdims=True)
#  96%|████████████████████████████████████████████████████████████████████████▏  | 3483/3618 [24:17:50<42:49, 19.04s/it]C:\Users\Shenorr\AppData\Roaming\Python\Python36\site-packages\scipy\stats\_distn_infrastructure.py:2664: RuntimeWarning: invalid value encountered in true_divide
#   pk = 1.0*pk / np.sum(pk, axis=axis, keepdims=True)
#  97%|████████████████████████████████████████████████████████████████████████▋  | 3508/3618 [24:22:53<22:06, 12.06s/it]C:\Users\Shenorr\AppData\Roaming\Python\Python36\site-packages\sklearn\base.py:197: FutureWarning: From version 0.24, get_params will raise an AttributeError if a parameter cannot be retrieved as an instance attribute. Previously it would return None.
#   FutureWarning)
#  98%|█████████████████████████████████████████████████████████████████████████▌ | 3548/3618 [24:31:26<25:32, 21.90s/it]C:\Users\Shenorr\AppData\Roaming\Python\Python36\site-packages\scipy\stats\_distn_infrastructure.py:2664: RuntimeWarning: invalid value encountered in true_divide
#   pk = 1.0*pk / np.sum(pk, axis=axis, keepdims=True)
#  98%|█████████████████████████████████████████████████████████████████████████▌ | 3550/3618 [24:32:00<21:57, 19.37s/it]C:\Users\Shenorr\AppData\Roaming\Python\Python36\site-packages\scipy\stats\_distn_infrastructure.py:2664: RuntimeWarning: invalid value encountered in true_divide
#   pk = 1.0*pk / np.sum(pk, axis=axis, keepdims=True)
#  99%|██████████████████████████████████████████████████████████████████████████ | 3575/3618 [24:37:17<08:32, 11.92s/it]C:\Users\Shenorr\AppData\Roaming\Python\Python36\site-packages\sklearn\base.py:197: FutureWarning: From version 0.24, get_params will raise an AttributeError if a parameter cannot be retrieved as an instance attribute. Previously it would return None.
#   FutureWarning)
# 100%|██████████████████████████████████████████████████████████████████████████▉| 3615/3618 [24:46:02<01:14, 24.75s/it]C:\Users\Shenorr\AppData\Roaming\Python\Python36\site-packages\scipy\stats\_distn_infrastructure.py:2664: RuntimeWarning: invalid value encountered in true_divide
#   pk = 1.0*pk / np.sum(pk, axis=axis, keepdims=True)
# 100%|██████████████████████████████████████████████████████████████████████████▉| 3617/3618 [24:46:38<00:21, 21.29s/it]C:\Users\Shenorr\AppData\Roaming\Python\Python36\site-packages\scipy\stats\_distn_infrastructure.py:2664: RuntimeWarning: invalid value encountered in true_divide
#   pk = 1.0*pk / np.sum(pk, axis=axis, keepdims=True)
# 100%|███████████████████████████████████████████████████████████████████████████| 3618/3618 [24:46:49<00:00, 24.66s/it]

# %%
valid_corr = meta_results[[col for col in meta_results.columns if "cellcorr" in col]].dropna(axis=0).index
valid_meta = meta_results.loc[valid_corr]
# _res = valid_meta[(valid_meta["corrPval"] < 0.15)].sort_values(by="corrMean",ascending=False)
# _res = _res.drop_duplicates(subset=["corrMean","entropy"])
# _res.head()["uuid"]

valid_meta.loc[valid_meta[[col for col in meta_results.columns if "cellcorr" in col]].idxmax()][["uuid"]+[col for col in meta_results.columns if "cellcorr" in col]]
# Out:
#             uuid  cellcorrPlasmacytoiddendriticcellsMean  \
# 3268   916286818                                   0.267
# 699   4080259338                                  -0.021
# 2490  1754390568                                   0.006
# 1139  2345350220                                  -0.042
# 85    2394451016                                  -0.043
# 2237  2591138118                                  -0.200
# 735    886524178                                   0.064
# 656   1773278244                                  -0.112
#
#       cellcorrNa?veCD8TcellMean  cellcorrNa?veCD4TcellMean  \
# 3268                      0.009                      0.184
# 699                       0.697                      0.073
# 2490                      0.233                      0.323
# 1139                     -0.000                      0.178
# 85                        0.405                     -0.016
# 2237                      0.038                     -0.279
# 735                       0.255                      0.031
# 656                       0.556                      0.087
#
#       cellcorrMonocytesMean  cellcorrCD8+effectormemoryTcellsMean  \
# 3268                  0.501                                 0.499
# 699                   0.119                                 0.557
# 2490                  0.291                                 0.432
# 1139                  0.618                                 0.056
# 85                    0.168                                 0.673
# 2237                  0.029                                -0.048
# 735                   0.215                                 0.032
# 656                   0.486                                 0.470
#
#       cellcorrCD4+centralmemoryTcellsMean  \
# 3268                               -0.127
# 699                                -0.231
# 2490                               -0.199
# 1139                               -0.261
# 85                                 -0.156
# 2237                                0.310
# 735                                -0.137
# 656                                -0.056
#
#       cellcorrCD4+effectormemoryTcellsMean  cellcorrBcellsMean
# 3268                                 0.114              -0.151
# 699                                  0.128               0.190
# 2490                                 0.410               0.408
# 1139                                -0.093              -0.024
# 85                                   0.084               0.275
# 2237                                 0.181               0.206
# 735                                  0.480               0.325
# 656                                  0.393               0.552

# %%
describe_results(str(1773278244))
# Out:
# params :
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>656</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>entropy</th>
#       <td>1.2892</td>
#     </tr>
#     <tr>
#       <th>corrMean</th>
#       <td>0.326</td>
#     </tr>
#     <tr>
#       <th>corrPval</th>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>cellcorrPlasmacytoiddendriticcellsMean</th>
#       <td>-0.112</td>
#     </tr>
#     <tr>
#       <th>cellcorrNa?veCD8TcellMean</th>
#       <td>0.556</td>
#     </tr>
#     <tr>
#       <th>cellcorrNa?veCD4TcellMean</th>
#       <td>0.087</td>
#     </tr>
#     <tr>
#       <th>cellcorrMonocytesMean</th>
#       <td>0.486</td>
#     </tr>
#     <tr>
#       <th>cellcorrCD8+effectormemoryTcellsMean</th>
#       <td>0.47</td>
#     </tr>
#     <tr>
#       <th>cellcorrCD4+centralmemoryTcellsMean</th>
#       <td>-0.056</td>
#     </tr>
#     <tr>
#       <th>cellcorrCD4+effectormemoryTcellsMean</th>
#       <td>0.393</td>
#     </tr>
#     <tr>
#       <th>cellcorrBcellsMean</th>
#       <td>0.552</td>
#     </tr>
#     <tr>
#       <th>PpFloorUnderQuantile_quantile</th>
#       <td>0.1</td>
#     </tr>
#     <tr>
#       <th>PpCleanHighIntraVar_how</th>
#       <td>std</td>
#     </tr>
#     <tr>
#       <th>PpCleanHighIntraVar_std_trh</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>PpCleanHighIntraVar_range_trh</th>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>PpCleanHighIntraVar_number_of_zeros</th>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>AggregateIntraVariance_how</th>
#       <td>median</td>
#     </tr>
#     <tr>
#       <th>PpEmpty_with_label_prop</th>
#       <td>False</td>
#     </tr>
#     <tr>
#       <th>PpEntropyBasedTotelSum_totel_sum_percentage</th>
#       <td>0.001</td>
#     </tr>
#     <tr>
#       <th>PpEntropyBasedTotelSum_with_norm</th>
#       <td>False</td>
#     </tr>
#     <tr>
#       <th>PpEntropyBasedTotelSum_low_intra_var_trh</th>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>PpEntropyBasedTotelSum_only_largest</th>
#       <td>True</td>
#     </tr>
#     <tr>
#       <th>PpEntropyBasedTotelSum_number_of_bins</th>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>BasicDeconv_normalize</th>
#       <td>True</td>
#     </tr>
#     <tr>
#       <th>BasicDeconv_cellMix</th>
#       <td>False</td>
#     </tr>
#     <tr>
#       <th>uuid</th>
#       <td>1773278244</td>
#     </tr>
#     <tr>
#       <th>PpAggToSpecificCells_cells_mapping</th>
#       <td>{'NOT_B</td>
#     </tr>
#   </tbody>
# </table>
# mixtures :
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th
td>
#       <td>0.01</td>
#       <td>0.00</td>
#       <td>0.01</td>
#       <td>0.03</td>
#       <td>0.12</td>
#       <td>0.25</td>
#       <td>0.13</td>
#       <td>0.01</td>
#       <td>0.00</td>
#       <td>0.01</td>
#       <td>0.04</td>
#       <td>0.10</td>
#       <td>0.20</td>
#       <td>0.09</td>
#       <td>0.16</td>
#     </tr>
#     <tr>
#       <th>Monocytes</th>
#       <td>0.51</td>
#       <td>0.33</td>
#       <td>0.29</td>
#       <td>0.30</td>
#       <td>0.32</td>
#       <td>0.45</td>
#       <td>0.38</td>
#       <td>0.62</td>
#       <td>0.55</td>
#       <td>0.59</td>
#       <td>0.25</td>
#       <td>0.31</td>
#       <td>0.38</td>
#       <td>0.46</td>
#       <td>0.38</td>
#       <td>0.26</td>
#       <td>0.39</td>
#       <td>0.32</td>
#       <td>0.36</td>
#       <td>0.36</td>
#       <td>0.25</td>
#       <td>0.46</td>
#       <td>0.48</td>
#       <td>0.20</td>
#       <td>0.36</td>
#       <td>0.41</td>
#       <td>0.54</td>
#       <td>0.27</td>
#       <td>0.44</td>
#       <td>0.40</td>
#       <td>0.18</td>
#       <td>0.52</td>
#       <td>0.46</td>
#       <td>0.44</td>
#       <td>0.46</td>
#       <td>0.63</td>
#       <td>0.50</td>
# mixtures details :
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>0</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>count</th>
#       <td>68.000000</td>
#     </tr>
#     <tr>
#       <th>mean</th>
#       <td>0.296225</td>
#     </tr>
#     <tr>
#       <th>std</th>
#       <td>0.237700</td>
#     </tr>
#     <tr>
#       <th>min</th>
#       <td>-0.179644</td>
#     </tr>
#     <tr>
#       <th>25%</th>
#       <td>0.145936</td>
#     </tr>
#     <tr>
#       <th>50%</th>
#       <td>0.317168</td>
#     </tr>
#     <tr>
#       <th>75%</th>
#       <td>0.463593</td>
#     </tr>
#     <tr>
#       <th>max</th>
#       <td>0.773370</td>
#     </tr>
#   </tbody>
# </table>

# %%
cpm = CellProportionsMeasure(how="correlation", return_dict_measure_statas=True, with_pvalue=True)
multi_result = _pipe.run_multi_signature_pipeline(A_all_vs,B_all_vs,meta_results,cpm)
multi_result
# Out:
# {'corrMean': -0.013, 'corrPval': 0.0, 'uuid': 1531059082}

# %%
# meta_results[~meta_results["PpEntropyBasedTotelSum_with_norm"].isna()][["corrMean","corrPval","entropy","uuid"]]

# %% [markdown]
# ## result

# %%
_res = meta_results[(meta_results["corrPval"] < 0.15)].sort_values(by="corrMean",ascending=False)
_res = _res.drop_duplicates(subset=["corrMean","entropy"])
_res.head()
# Out:
#        entropy  corrMean  corrPval  cellcorrPlasmacytoiddendriticcellsMean  \
# 665   0.959030     0.777     0.000                                     NaN
# 3150  0.000000     0.722     0.101                                     NaN
# 2176  1.042829     0.716     0.000                                     NaN
# 1686  0.583179     0.706     0.010                                     NaN
# 1051  0.520947     0.663     0.030                                   0.096
#
#       cellcorrNa?veCD8TcellMean  cellcorrNa?veCD4TcellMean  \
# 665                         NaN                     -0.047
# 3150                        NaN                        NaN
# 2176                      0.185                     -0.136
# 1686                        NaN                        NaN
# 1051                      0.048                     -0.156
#
#       cellcorrMonocytesMean  cellcorrCD8+effectormemoryTcellsMean  \
# 665                   0.403                                -0.044
# 3150                  0.062                                   NaN
# 2176                  0.342                                 0.188
# 1686                  0.338                                   NaN
# 1051                  0.230                                 0.063
#
#       cellcorrCD4+centralmemoryTcellsMean  \
# 665                                   NaN
# 3150                                  NaN
# 2176                               -0.143
# 1686                                  NaN
# 1051                                0.159
#
#       cellcorrCD4+effectormemoryTcellsMean  ...  \
# 665                                  0.400  ...
# 3150                                   NaN  ...
# 2176                                 0.023  ...
# 1686                                 0.167  ...
# 1051                                 0.147  ...
#
#       PpEntropyBasedOnlyLargest_with_norm  \
# 665                                   NaN
# 3150                                  NaN
# 2176                                  NaN
# 1686                                  NaN
# 1051                                  NaN
#
#      PpEntropyBasedOnlyLargest_low_intra_var_trh  \
# 665                                          NaN
# 3150                                         NaN
# 2176                                         NaN
# 1686                                         NaN
# 1051                                         NaN
#
#      PpEntropyBasedOnlyLargest_number_of_bins PpDepDeBased_n_genes_per_cell  \
# 665                                       NaN                           NaN
# 3150                                      NaN                           NaN
# 2176                                      NaN                           NaN
# 1686                                      NaN                            20
# 1051                                      NaN                           NaN
#
#      PpDepDeBased_intansity_type PpDepDeBased_is_agg_cells  \
# 665                          NaN                       NaN
# 3150                         NaN                       NaN
# 2176                         NaN                       NaN
# 1686                     Intensi                     False
# 1051                         NaN                       NaN
#
#      PpDepDeBased_n_of_genes PpSvmSignature_n_features  \
# 665                      NaN                       NaN
# 3150                     NaN                       NaN
# 2176                     NaN                       NaN
# 1686                      80                       NaN
# 1051                     NaN                       NaN
#
#      PpSvmSignature_with_norm PpAggToSpecificCells_cells_mapping
# 665                       NaN                            {'NOT_B
# 3150                      NaN                                NaN
# 2176                      NaN                                NaN
# 1686                      NaN                                NaN
# 1051                      NaN                            {'NOT_B
#
# [5 rows x 42 columns]

# %%
_res = meta_results.sort_values(by="corrMean",ascending=False)[["corrMean","corrPval","entropy","uuid"]]
_res[(_res["corrMean"] > 0.5)&(_res["entropy"] > 0.5)&(_res["corrPval"] < 0.05)].sort_values(by="entropy")
# Out:
#       corrMean  corrPval   entropy        uuid
# 3417     0.634     0.020  0.513075   803631068
# 1051     0.663     0.030  0.520947   152838272
# 1491     0.706     0.000  0.583179  1182206648
# 1685     0.706     0.000  0.583179  4092746054
# 1686     0.706     0.010  0.583179   272876444
# 1490     0.706     0.010  0.583179   606009262
# 1295     0.706     0.000  0.583179  1526554448
# 1296     0.706     0.010  0.583179  2076791052
# 451      0.508     0.000  0.622584  3736338038
# 60       0.508     0.010  0.622584  2559935818
# 450      0.508     0.010  0.622584  3250337408
# 61       0.508     0.025  0.622584  3050003922
# 255      0.508     0.010  0.622584  4271062196
# 256      0.508     0.010  0.622584   528934894
# 2010     0.507     0.000  0.628188  1529438482
# 1815     0.507     0.010  0.628188  2628477044
# 2011     0.507     0.000  0.628188  2137867154
# 1816     0.507     0.030  0.628188  3161570200
# 2205     0.507     0.010  0.628188  2613138302
# 2206     0.507     0.010  0.628188  3158662994
# 887      0.511     0.010  0.900444  3287728832
# 2225     0.635     0.010  0.916353  1195081958
# 664      0.777     0.000  0.959030  3040854280
# 665      0.777     0.000  0.959030  3197819684
# 2176     0.716     0.000  1.042829  2961582540
# 487      0.538     0.010  1.171211  3713639276
# 1064     0.592     0.035  1.263716  1709004252

# %%
# meta_results[(meta_results["rmsePval"] < 0.15)&(meta_results["corrPval"] < 0.15)].sort_values(by="corrMean",ascending=False).head(10)

# %% [markdown]
# # best results

# %% [markdown]
# ## get best results

# %%
def build_distance_matrix() :
    uuid_to_results = {}
    for uuid in meta_results["uuid"] : 
        params = meta_results[meta_results["uuid"] == int(uuid)].T.copy(deep=True).dropna()
        
        best_results_and_known = _pipe.load_results_from_archive(uuid)
        best_results=best_results_and_known["result"]
        res_values = best_results.sort_index(axis=0).sort_index(axis=1).values
        
        uuid_to_results[uuid] = res_values
    
    results = {}
    looked_uuids = {}
    for uuid,res in uuid_to_results.items():
        if uuid in looked_uuids.keys():
            continue
            
        neighbors = [] 
        for sec_uuid,sec_res in uuid_to_results.items():
            if (res == sec_res).all() :
                neighbors.append(sec_uuid)
                looked_uuids[sec_uuid] = sec_uuid
        if len(neighbors) > 1 :
            results[uuid] = neighbors
    
    clusters = [] 
    for _,cluster in  results.items():
        uuids = [] 
        for uuid in cluster : 
            params = meta_results[meta_results["uuid"] == int(uuid)].T.copy(deep=True).dropna()
            uuids.append(params)
        clusters.append(pd.concat(uuids,axis=1))
        
    
    return clusters
      
def plot_correlation_per_cell(uuids) : 
    if type(uuids) is str : 
        uuids = [uuids]
    
    max_corr_per_cell = {}
    best_param_per_cell = {}
    
    for uuid in meta_results["uuid"] : 
        params = meta_results[meta_results["uuid"] == int(uuid)].T.copy(deep=True).dropna()
        
        best_results_and_known = _pipe.load_results_from_archive(uuid)
        best_results=best_results_and_known["result"]
        best_known=best_results_and_known["known"]
        mapping = GlobalUtils.get_corospanding_mixtures_map(best_known,best_results)
        best_known = best_known.rename(columns=mapping)
        best_known = best_known[[col for col in mapping.values()]]

        mutual_col = best_known.columns.intersection(best_results.columns)
        best_results = best_results[mutual_col]
        best_known = best_known[mutual_col]

        corr_per_cell =  best_results.T.corrwith(best_known.T,method="spearman")
        
        for cell in corr_per_cell.index : 
            if cell in max_corr_per_cell.keys() : 
                if corr_per_cell[cell] > max_corr_per_cell[cell] :
                    max_corr_per_cell[cell] = corr_per_cell[cell]
                    best_param_per_cell[cell] = params
            else : 
                max_corr_per_cell[cell] = corr_per_cell[cell]
                best_param_per_cell[cell] = params
    
    return max_corr_per_cell,best_param_per_cell

def plot_results_vs_known_pca(best_results,best_known):
    pca = PCA(n_components=2)
    pca.fit(pd.concat([best_results,best_known],axis=1).T)

    deconv_principalcomp = pca.transform(best_results.T)
    known_principalcomp = pca.transform(best_known.T)

    deconv_principalDf =pd.DataFrame(data = deconv_principalcomp
                 , columns = ['principal component 1', 'principal component 2'],index = best_results.columns)
    known_principalDf = pd.DataFrame(data = known_principalcomp
                 , columns = ['principal component 1', 'principal component 2'],index = best_known.columns)

    deconv_principalDf["color"] = "b"
    known_principalDf["color"] = "r"

    principalDf = deconv_principalDf.append(known_principalDf)
    fig = plt.figure(figsize = (25,15))
    ax = fig.add_subplot(1,1,1) 
    ax.set_xlabel('Principal Component 1', fontsize = 15)
    ax.set_ylabel('Principal Component 2', fontsize = 15)
    ax.set_title('blue - deconvolution result,red -  known proportions', fontsize = 20)

    ax.scatter(principalDf['principal component 1'], principalDf['principal component 2'],c=principalDf['color'], s = 50)

    for mixture in range(deconv_principalcomp.shape[0]):
        deconv_point = deconv_principalcomp[mixture,:]
        known_point = known_principalcomp[mixture,:]
        plt.plot([deconv_point[0],known_point[0]],[deconv_point[1],known_point[1]], ':')

    for i, txt in enumerate(principalDf.index):
        ax.annotate(txt, (principalDf['principal component 1'].iloc[i], principalDf['principal component 2'].iloc[i]))

def describe_results(uuids,with_per_mixture_plot = False,with_mixtures_pca = False) : 
    if type(uuids) is str : 
        uuids = [uuids]
    
    for uuid in uuids : 
        params = meta_results[meta_results["uuid"] == int(uuid)].T.copy(deep=True).dropna()
        print("params : ")
        display(HTML(params.to_html()))


        best_results_and_known = _pipe.load_results_from_archive(uuid)
        best_results=best_results_and_known["result"]
        best_known=best_results_and_known["known"]
        mapping = GlobalUtils.get_corospanding_mixtures_map(best_known,best_results)
        best_known = best_known.rename(columns=mapping)
        best_known = best_known[[col for col in mapping.values()]]

        mutual_col = best_known.columns.intersection(best_results.columns)
        best_results = best_results[mutual_col]
        best_known = best_known[mutual_col]

        print("mixtures : ")
        display(HTML(best_results.to_html()))

        print("mixtures details :")
        display(HTML(best_results.corrwith(best_known,method="spearman").describe().to_frame().to_html()))

        cytof_plots.plot_mass_to_cytof_scatter_all_on_one(best_results,best_known,best_results)
        if with_per_mixture_plot : 
            cytof_plots.plot_mass_to_cytof_scatter(best_results,best_known,best_results)
        if with_mixtures_pca : 
            plot_results_vs_known_pca(best_results,best_known)

# %%
describe_results("1568926666")
# Out:
# params :
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>entropy</th>
#     </tr>
#     <tr>
#       <th>corrMean</th>
#     </tr>
#     <tr>
#       <th>corrPval</th>
#     </tr>
#     <tr>
#       <th>cellcorrPlasmacytoiddendriticcellsMean</th>
#     </tr>
#     <tr>
#       <th>cellcorrNa?veCD8TcellMean</th>
#     </tr>
#     <tr>
#       <th>cellcorrNa?veCD4TcellMean</th>
#     </tr>
#     <tr>
#       <th>cellcorrMonocytesMean</th>
#     </tr>
#     <tr>
#       <th>cellcorrCD8+effectormemoryTcellsMean</th>
#     </tr>
#     <tr>
#       <th>cellcorrCD4+centralmemoryTcellsMean</th>
#     </tr>
#     <tr>
#       <th>cellcorrCD4+effectormemoryTcellsMean</th>
#     </tr>
#     <tr>
#       <th>cellcorrBcellsMean</th>
#     </tr>
#     <tr>
#       <th>PpFloorUnderQuantile_quantile</th>
#     </tr>
#     <tr>
#       <th>PpKeepSpecificCells_cells_list</th>
#     </tr>
#     <tr>
#       <th>PpCleanHighIntraVar_how</th>
#     </tr>
#     <tr>
#       <th>PpCleanHighIntraVar_std_trh</th>
#     </tr>
#     <tr>
#       <th>PpCleanHighIntraVar_range_trh</th>
#     </tr>
#     <tr>
#       <th>PpCleanHighIntraVar_number_of_zeros</th>
#     </tr>
#     <tr>
#       <th>AggregateIntraVariance_how</th>
#     </tr>
#     <tr>
#       <th>PpEmpty_with_label_prop</th>
#     </tr>
#     <tr>
#       <th>PpEntropyBasedTotelSum_totel_sum_percentage</th>
#     </tr>
#     <tr>
#       <th>PpEntropyBasedTotelSum_with_norm</th>
#     </tr>
#     <tr>
#       <th>PpEntropyBasedTotelSum_low_intra_var_trh</th>
#     </tr>
#     <tr>
#       <th>PpEntropyBasedTotelSum_only_largest</th>
#     </tr>
#     <tr>
#       <th>PpEntropyBasedTotelSum_number_of_bins</th>
#     </tr>
#     <tr>
#       <th>BasicDeconv_normalize</th>
#     </tr>
#     <tr>
#       <th>BasicDeconv_cellMix</th>
#     </tr>
#     <tr>
#       <th>uuid</th>
#     </tr>
#     <tr>
#       <th>PpEntropyBased_n_genes_per_cell</th>
#     </tr>
#     <tr>
#       <th>PpEntropyBased_gene_entropy_trh</th>
#     </tr>
#     <tr>
#       <th>PpEntropyBased_with_norm</th>
#     </tr>
#     <tr>
#       <th>PpEntropyBased_number_of_bins</th>
#     </tr>
#     <tr>
#       <th>PpEntropyBasedOnlyLargest_n_genes_per_cell</th>
#     </tr>
#     <tr>
#       <th>PpEntropyBasedOnlyLargest_with_norm</th>
#     </tr>
#     <tr>
#       <th>PpEntropyBasedOnlyLargest_low_intra_var_trh</th>
#     </tr>
#     <tr>
#       <th>PpEntropyBasedOnlyLargest_number_of_bins</th>
#     </tr>
#     <tr>
#       <th>PpDepDeBased_n_genes_per_cell</th>
#     </tr>
#     <tr>
#       <th>PpDepDeBased_intansity_type</th>
#     </tr>
#     <tr>
#       <th>PpDepDeBased_is_agg_cells</th>
#     </tr>
#     <tr>
#       <th>PpDepDeBased_n_of_genes</th>
#     </tr>
#     <tr>
#       <th>PpSvmSignature_n_features</th>
#     </tr>
#     <tr>
#       <th>PpSvmSignature_with_norm</th>
#     </tr>
#     <tr>
#       <th>PpAggToSpecificCells_cells_mapping</th>
#     </tr>
#   </tbody>
# </table>
# mixtures :
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>38_v1</th>
#       <th>42_v1</th>
#       <th>42_v2</th>
#       <th>42_v3</th>
#       <th>44_v1</th>
#       <th>44_v2</th>
#       <th>44_v3</th>
#       <th>46_v1</th>
#       <th>46_v3</th>
#       <th>47_v1</th>
#       <th>38_v2</th>
#       <th>47_v2</th>
#       <th>47_v3</th>
#       <th>48_v1</th>
#       <th>48_v2</th>
#       <th>48_v3</th>
#       <th>29_v1</th>
#       <th>29_v2</th>
#       <th>29_v3</th>
#       <th>30_v1</th>
#       <th>30_v2</th>
#       <th>38_v3</th>
#       <th>30_v3</th>
#       <th>31_v1</th>
#       <th>31_v2</th>
#       <th>31_v3</th>
#       <th>32_v1</th>
#       <th>32_v2</th>
#       <th>32_v3</th>
#       <th>33_v1</th>
#       <th>33_v3</th>
#       <th>39_v1</th>
#       <th>35_v1</th>
#       <th>35_v2</th>
#       <th>35_v3</th>
#       <th>36_v1</th>
#       <th>36_v2</th>
#       <th>36_v3</th>
#       <th>37_v1</th>
#       <th>37_v2</th>
#       <th>37_v3</th>
#       <th>20_v1</th>
#       <th>39_v2</th>
#       <th>20_v2</th>
#       <th>20_v3</th>
#       <th>21_v1</th>
#       <th>21_v2</th>
#       <th>21_v3</th>
#       <th>22_v1</th>
#       <th>22_v2</th>
#       <th>22_v3</th>
#       <th>23_v1</th>
#       <th>23_v2</th>
#       <th>23_v3</th>
#       <th>24_v1</th>
#       <th>24_v2</th>
#       <th>24_v3</th>
#       <th>26_v1</th>
#       <th>26_v2</th>
#       <th>26_v3</th>
#       <th>27_v1</th>
#       <th>27_v2</th>
#       <th>27_v3</th>
#       <th>40_v1</th>
#       <th>28_v1</th>
#       <th>28_v2</th>
#       <th>28_v3</th>
#       <th>40_v3</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th
td>
#     </tr>
#     <tr>
#       <th>std</th>
#       <td>0.140246</td>
#     </tr>
#     <tr>
#       <th>min</th>
#       <td>-0.082479</td>
#     </tr>
#     <tr>
#       <th>25%</th>
#       <td>0.411457</td>
#     </tr>
#     <tr>
#       <th>50%</th>
#       <td>0.488130</td>
#     </tr>
#     <tr>
#       <th>75%</th>
#       <td>0.588650</td>
#     </tr>
#     <tr>
#       <th>max</th>
#       <td>0.763763</td>
#     </tr>
#   </tbody>
# </table>

# %%
describe_results("803631068")
# Out:
# params :
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>3417</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>entropy</th>
#       <td>0.513075</td>
#     </tr>
#     <tr>
#       <th>corrMean</th>
#       <td>0.634</td>
#     </tr>
#     <tr>
#       <th>corrPval</th>
#       <td>0.02</td>
#     </tr>
#     <tr>
#       <th>cellcorrMonocytesMean</th>
#       <td>0.178</td>
#     </tr>
#     <tr>
#       <th>cellcorrCD4+effectormemoryTcellsMean</th>
#       <td>0.116</td>
#     </tr>
#     <tr>
#       <th>AggregateIntraVariance_how</th>
#       <td>median</td>
#     </tr>
#     <tr>
#       <th>PpEmpty_with_label_prop</th>
#       <td>False</td>
#     </tr>
#     <tr>
#       <th>BasicDeconv_normalize</th>
#       <td>True</td>
#     </tr>
#     <tr>
#       <th>BasicDeconv_cellMix</th>
#       <td>False</td>
#     </tr>
#     <tr>
#       <th>uuid</th>
#       <td>803631068</td>
#     </tr>
#     <tr>
#       <th>PpEntropyBased_n_genes_per_cell</th>
#       <td>100</td>
#     </tr>
#     <tr>
#       <th>PpEntropyBased_gene_entropy_trh</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>PpEntropyBased_with_norm</th>
#       <td>False</td>
#     </tr>
#     <tr>
#       <th>PpEntropyBased_number_of_bins</th>
#       <td>0</td>
#     </tr>
#   </tbody>
# </table>
# mixtures :
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>38_v1</th>
#       <th>42_v1</th>
#       <th>42_v2</th>
#       <th>42_v3</th>
#       <th>44_v1</th>
#       <th>44_v2</th>
#       <th>44_v3</th>
#       <th>46_v1</th>
#       <th>46_v3</th>
#       <th>47_v1</th>
#       <th>38_v2</th>
#       <th>47_v2</th>
#       <th>47_v3</th>
#       <th>48_v1</th>
#       <th>48_v2</th>
#       <th>48_v3</th>
#       <th>29_v1</th>
#       <th>29_v2</th>
#       <th>29_v3</th>
#       <th>30_v1</th>
#       <th>30_v2</th>
#       <th>38_v3</th>
#       <th>30_v3</th>
#       <th>31_v1</th>
#       <th>31_v2</th>
#       <th>31_v3</th>
#       <th>32_v1</th>
#       <th>32_v2</th>
#       <th>32_v3</th>
#       <th>33_v1</th>
#       <th>33_v3</th>
#       <th>39_v1</th>
#       <th>35_v1</th>
#       <th>35_v2</th>
#       <th>35_v3</th>
#       <th>36_v1</th>
#       <th>36_v2</th>
#       <th>36_v3</th>
#       <th>37_v1</th>
#       <th>37_v2</th>
#       <th>37_v3</th>
#       <th>20_v1</th>
#       <th>39_v2</th>
#       <th>20_v2</th>
#       <th>20_v3</th>
#       <th>21_v1</th>
#       <th>21_v2</th>
#       <th>21_v3</th>
#       <th>22_v1</th>
#       <th>22_v2</th>
#       <th>22_v3</th>
#       <th>23_v1</th>
#       <th>23_v2</th>
#       <th>23_v3</th>
#       <th>24_v1</th>
#       <th>24_v2</th>
#       <th>24_v3</th>
#       <th>26_v1</th>
#       <th>26_v2</th>
#       <th>26_v3</th>
#       <th>27_v1</th>
#       <th>27_v2</th>
#       <th>27_v3</th>
#       <th>40_v1</th>
#       <th>28_v1</th>
#       <th>28_v2</th>
#       <th>28_v3</th>
#       <th>40_v3</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>B cells</th>
#       <td>0.00</td>
#       <td>0.00</td>
#       <td>0.00</td>
#       <td>0.00</td>
#       <td>0.00</td>
#       <td>0.00</td>
#       <td>0.00</td>
#       <td>0.00</td>
#       <td>0.00</td>
#       <td>0.0</td>
#       <td>0.00</td>
#       <td>0.00</td>
#       <td>0.00</td>
#       <td>0.0</td>
#       <td>0.00</td>
#       <td>0.00</td>
#       <td>0.00</td>
#       <td>0.00</td>
#       <td>0.00</td>
#       <td>0.00</td>
#       <td>0.00</td>
#       <td>0.00</td>
#       <td>0.00</td>
#       <td>0.00</td>
#       <td>0.00</td>
#       <td>0.00</td>
#       <td>0.00</td>
#       <td>0.00</td>
#       <td>0.00</td>
#       <td>0.00</td>
#       <td>0.00</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.00</td>
#       <td>0.00</td>
#       <td>0.00</td>
#       <td>0.00</td>
#       <td>0.00</td>
#       <td>0.00</td>
#       <td>0.00</td>
#       <td>0.00</td>
#       <td>0.0</td>
#       <td>0.00</td>
#       <td>0.00</td>
#       <td>0.00</td>
#       <td>0.00</td>
#       <td>0.00</td>
#       <td>0.00</td>
#       <td>0.00</td>
#       <td>0.00</td>
#       <td>0.00</td>
#       <td>0.00</td>
#       <td>0.00</td>
#       <td>0.00</td>
#       <td>0.00</td>
#       <td>0.00</td>
#       <td>0.00</td>
#       <td>0.0</td>
#       <td>0.00</td>
#       <td>0.00</td>
#       <td>0.00</td>
#       <td>0.00</td>
#       <td>0.0</td>
#       <td>0.00</td>
#       <td>0.00</td>
#       <td>0.00</td>
#       <td>0.00</td>
#       <td>0.00</td>
#     </tr>
#     <tr>
#       <th